# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuzay3t/Image-Classification/blob/main/Copy_of__Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification Starter Notebook
#
# Welcome to the Image Classification Starter Notebook for our Hacktoberfest competition! 🚀
#
# In this notebook, you'll find a ready-to-use Python script that provides a solid foundation for building an image classifier to classify buildings into three classes: Bungalow, Highrise, and Storey buildings.
#
# ## Getting Started
#
# To get started, follow these steps:
#
# 1. **Clone the Repository**: Begin by cloning this repository to your local machine.
#
# 2. **Organize Your Data**: Ensure that your image data is organized in the `Data` directory, with subdirectories for each class (`Bungalow`, `Highrise`, `Storey-Building`).
#
# 3. **Open the Notebook**: Open this notebook in a Jupyter environment.
#
# 4. **Follow the Code**: The notebook contains commented code that guides you through the process of setting up the data, building and training the model, and evaluating its performance.
#
# 5. **Experiment and Contribute**: Feel free to experiment with different architectures, hyperparameters, or augmentation techniques. If you come up with improvements, consider contributing them back to the project!
#
# ## Important Notes
#
# - Ensure that you have TensorFlow and related dependencies installed in your environment.
# - If you encounter any issues or have questions, don't hesitate to reach out. We're here to help!
#
# Happy coding, and let's build an amazing image classifier together!

# %%
# Import necessary libraries
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
from tensorflow.keras.layers import Dropout

# %%
# !ls /content
# Out:
#  10B21B6B-95F5-4079-8628-6DAE76E348B4.jpeg
#  13B889F1-556B-47B3-8FE0-1BD4E1411042.jpeg
#  13F5894E-50CE-490E-A037-157FA1FB04ED.jpeg
#  20230927_182105.jpeg
#  20231004_112620.jpeg
#  20231004_115629.jpeg
#  20231004_115646.jpeg
#  20231004_115650.jpeg
#  20231004_120132.jpeg
#  20231004_120153.jpeg
#  20231004_120200.jpeg
#  233C4D1A-D26A-4146-923F-0E7423C25E75.jpeg
#  2525339E-981A-41D8-ACF8-090646D92AB4.jpeg
#  346B19E7-D0D6-4EFD-BF9E-516BF2EF88DA.jpeg
#  37299791-9D8A-4329-8F31-6520F9DF40FE.jpeg
#  3EAFA182-ADEC-4D27-9C19-C46FFEACA5A4.jpeg
#  46DC1D81-E5CC-4FBF-B88D-DDFB90532C18.jpeg
#  53F9FA3C-2DEA-47AB-B69E-8DCCDA120172.jpeg
#  59E94C93-1C1E-4D39-BB24-D90087C1E992.jpeg
# '5-Bedroom-Duplex-Houses-For-sale-at-All-Nigeria copy.jpeg'
#  5-Bedroom-Duplex-Houses-For-sale-at-All-Nigeria.jpeg
#  5F4EE75D-71C3-4183-ABB3-1C3A75BCCCBA.jpeg
#  6398F29D-B695-4DDB-AFEC-222E92D054E6.jpeg
#  682FDE99-703D-49AB-9C8E-6A8BF4DC8295.jpeg
#  6AF68D33-53F8-4584-B55F-46862E6DCBE1.jpeg
#  7F0E2688-77C8-4EEF-BEF5-63A8A0FAE7B5.jpeg
#  81302B3F-5D25-4FED-9232-10A32DECE7C1.jpeg
#  82E1BEAE-BB35-46AE-A61E-6EF691F718B9.jpeg
#  9C49C23F-9A0C-44A6-949C-EF12E74A12AD.jpeg
#  9FA20F31-AB3A-418B-AE28-69C6284B08D4.jpeg
#  A8D47BBB-0350-41EF-A074-173C65784047.jpeg
#  ABA24D3B-0F64-4D47-8798-A1D36CA887CB.jpeg
#  anu_Storey_1.jpeg
#  anu_Storey_2.jpeg
#  anu_Storey_3.jpeg
#  anu_Storey_4.jpeg
# 'anu_storey_5 (1).jpeg'
#  anu_storey_6.jpeg
#  anu_storey_7.jpeg
#  anu_storey_8.jpeg
#  anu_storey_9.jpeg
# 'ayn_storey (10).jpeg'
# 'ayn_storey (11).jpeg'
# 'ayn_storey (12).jpeg'
# 'ayn_storey (13).jpeg'
# 'ayn_storey (14).jpeg'
# 'ayn_storey (15).jpeg'
# 'ayn_storey (16).jpeg'
# 'ayn_storey (17).jpeg'
# 'ayn_storey (18).jpeg'
# 'ayn_storey (19).jpeg'
# 'ayn_storey (1).jpeg'
# 'ayn_storey (20).jpeg'
# 'ayn_storey (21).jpeg'
# 'ayn_storey (22).jpeg'
# 'ayn_storey (23).jpeg'
# 'ayn_storey (24).jpeg'
# 'ayn_storey (25).jpeg'
# 'ayn_storey (26).jpeg'
# 'ayn_storey (27).jpeg'
# 'ayn_storey (28).jpeg'
# 'ayn_storey (29).jpeg'
# 'ayn_storey (2).jpeg'
# 'ayn_storey (30).jpeg'
# 'ayn_storey (31).jpeg'
# 'ayn_storey (32).jpeg'
# 'ayn_storey (33).jpeg'
# 'ayn_storey (34).jpeg'
# 'ayn_storey (35).jpeg'
# 'ayn_storey (36).jpeg'
# 'ayn_storey (37).jpeg'
# 'ayn_storey (38).jpeg'
# 'ayn_storey (39).jpeg'
# 'ayn_storey (3).jpeg'
# 'ayn_storey (40).jpeg'
# 'ayn_storey (41).jpeg'
# 'ayn_storey (42).jpeg'
# 'ayn_storey (43).jpeg'
# 'ayn_storey (44).jpeg'
# 'ayn_storey (45).jpeg'
# 'ayn_storey (46).jpeg'
# 'ayn_storey (47).jpeg'
# 'ayn_storey (48).jpeg'
# 'ayn_storey (49).jpeg'
# 'ayn_storey (4).jpeg'
# 'ayn_storey (50).jpeg'
# 'ayn_storey (51).jpeg'
# 'ayn_storey (52).jpeg'
# 'ayn_storey (53).jpeg'
# 'ayn_storey (54).jpeg'
# 'ayn_storey (55).jpeg'
# 'ayn_storey (56).jpeg'
# 'ayn_storey (57).jpeg'
# 'ayn_storey (58).jpeg'
# 'ayn_storey (59).jpeg'
# 'ayn_storey (5).jpeg'
# 'ayn_storey (6).jpeg'
# 'ayn_storey (7).jpeg'
# 'ayn_storey (8).jpeg'
# 'ayn_storey (9).jpeg'
# 'ay_storey (10).jpeg'
# 'ay_storey (11).jpeg'
# 'ay_storey (12).jpeg'
# 'ay_storey  (13).jpeg'
# 'ay_storey (1).jpeg'
# 'ay_storey 2.jpeg'
# 'ay_storey (2).jpeg'
# 'ay_storey (4).jpeg'
# 'ay_storey (5).jpeg'
# 'ay_storey (6).jpeg'
# 'ay_storey (7).jpeg'
# 'ay_storey (8).jpeg'
# 'ay_storey (9).jpeg'
#  ay_storey.jpeg
#  B3BEB3CA-F9D0-491F-84B0-7DAA4CBE0BF8.jpeg
#  B56BFB36-97C0-470C-BFEE-57580C110F93.jpeg
#  B7D48B10-E5A9-4890-960A-188DD42A70BD.jpeg
#  BBA6FFBB-9067-41A8-9D30-6DD54DAF198E.jpeg
#  BE5764ED-8917-49DE-9B9E-C5ACC9036943.jpeg
#  BEF73D86-AF77-41C1-8755-ED2A5AF6CF5C.jpeg
# 'Building Types.zip'
#  C67C7943-5FE7-4ABD-968C-00D43426D145.jpeg
#  C83137D8-EC8F-4947-B587-E58FB3A92CEC.jpeg
#  C8CCB999-8F4B-4DDF-B0EA-DE60229C46CE.jpeg
#  CDEC03DE-C55C-4F1D-B9C9-4EE1B64289DF.jpeg
# 'Dantochi_Storey-Building(1).jpeg'
# 'Dantochi_Storey-Building(2).jpeg'
# 'Dantochi_Storey-Building-(3).jpeg'
# 'Dantochi_Storey-Building-(4).jpeg'
# 'Dantochi_Storey-Building(5).jpeg'
# 'Dantochi_Storey-Building-(6).jpeg'
# 'Dantochi_Storey-Building(7).jpeg'
# 'Dantochi_Storey-Building-(8).jpeg'
#  debola_storey1.jpeg
#  debola_storey2.jpeg
#  debola_storey3.jpeg
#  debola_storey4.jpeg
#  E4271FB5-E545-4088-8F26-C3C9BF145A54.jpeg
#  F0E311C7-545B-4275-A178-F473ED673EF8.jpeg
#  F9D98AB0-EA7E-4F1F-99DD-F670F08EF780.jpeg
#  Fari-Storey-building-1.jpeg
#  Fari-Storey-building-2.jpeg
#  Fari-Storey-building-3.jpeg
#  Fari-Storey-building-4.jpeg
#  Fari-Storey-building-5.jpeg
#  Fari-Storey-building-6.jpeg
#  Fari-Storey-building-7.jpeg
#  Fari-Storey-building-8.jpeg
#  Fari-Storey-building-9.jpeg
#  Fari-Storey-building.jpeg
#  gv-tosin.jpeg
# 'Image 2023-10-04 at 17.36 (1).jpeg'
# 'Image 2023-10-04 at 17.36 (2).jpeg'
# 'images (21) copy.jpeg'
# 'images (21).jpeg'
# 'images (22) copy.jpeg'
# 'images (22).jpeg'
# 'images (23) copy 2.jpeg'
# 'images (23) copy 3.jpeg'
# 'images (23) copy 4.jpeg'
# 'images (23) copy.jpeg'
# 'images (23).jpeg'
# 'images (25).jpeg'
# 'images (30).jpeg'
# 'images (31) copy.jpeg'
# 'images (31).jpeg'
# 'images (32).jpeg'
# 'images (33).jpeg'
# 'images (34).jpeg'
# 'images (35).jpeg'
# 'images (37).jpeg'
# 'images (38) copy 2.jpeg'
# 'images (38) copy.jpeg'
# 'images (38).jpeg'
# 'images (39) copy.jpeg'
# 'images (39).jpeg'
# 'images (41) copy.jpeg'
# 'images (41).jpeg'
# 'images (42) copy 2.jpeg'
# 'images (42) copy.jpeg'
# 'images (42).jpeg'
# 'images (43) copy 2.jpeg'
# 'images (43) copy.jpeg'
# 'images (43).jpeg'
# 'images (45) copy 2.jpeg'
# 'images (45) copy.jpeg'
# 'images (45).jpeg'
# 'images (46).jpeg'
# 'images (48).jpeg'
# 'images (49).jpeg'
# 'images (51).jpeg'
# 'images (52).jpeg'
# 'images (53).jpeg'
# 'images (55).jpeg'
# 'images (56).jpeg'
# 'images (57).jpeg'
# 'images (58).jpeg'
# 'images (59).jpeg'
# 'images (60).jpeg'
# 'images (61) copy.jpeg'
# 'images (61).jpeg'
# 'images (62).jpeg'
# 'images (63).jpeg'
# 'images (65).jpeg'
# 'images (66).jpeg'
# 'images (67).jpeg'
# 'images (68).jpeg'
# 'images (69).jpeg'
# 'images (70).jpeg'
# 'images (71).jpeg'
# 'images (73).jpeg'
# 'images (74).jpeg'
# 'images (75).jpeg'
# 'images (76).jpeg'
# 'images (77).jpeg'
#  IMG_20210629_181252.jpeg
#  IMG_20220129_152309.jpeg
#  IMG_20220226_155656.jpeg
#  IMG_20220226_155703.jpeg
#  IMG_20220226_155728.jpeg
#  IMG_20220226_160822.jpeg
#  IMG_20220226_160827.jpeg
#  IMG_20220227_073025.jpeg
#  IMG_20220227_073031.jpeg
#  IMG_20220310_111230.jpeg
#  IMG_20220415_065619.jpeg
#  IMG_20220502_065425.jpeg
#  IMG_20220905_075644.jpeg
#  IMG_20220905_075655.jpeg
#  IMG_20221102_154107.jpeg
#  IMG_20230430_084744.jpeg
#  IMG_20230530_104716.jpeg
#  IMG_20230714_143711.jpeg
#  IMG_20230905_100246.jpeg
#  IMG_20230924_122511_659.jpeg
#  IMG-20231002-WA0073.jpeg
#  IMG-20231002-WA0078.jpeg
#  IMG_20231003_164633_389.jpeg
#  IMG_20231004_131831_455.jpeg
#  IMG_20231004_131835_773.jpeg
#  IMG-20231004-WA0058.jpeg
#  IMG-20231004-WA0067.jpeg
#  IMG-20231004-WA0070.jpeg
#  IMG-20231004-WA0071.jpeg
#  IMG-20231004-WA0074.jpeg
#  IMG-20231004-WA0075.jpeg
#  IMG-20231004-WA0078.jpeg
#  IMG-20231004-WA0079.jpeg
#  IMG-20231004-WA0080.jpeg
#  IMG-20231004-WA0081.jpeg
#  IMG_20231005_113845_187.jpeg
#  IMG_20231005_114034_852.jpeg
#  IMG_20231005_114047_771.jpeg
#  IMG_20231005_114249_009.jpeg
#  IMG_20231005_114333_044.jpeg
#  IMG_20231005_114609_743.jpeg
#  IMG_20231005_114616_621.jpeg
#  IMG_20231005_114633_136.jpeg
#  IMG_20231005_114638_752.jpeg
#  IMG_20231005_114716_960.jpeg
#  IMG_20231005_114723_197.jpeg
#  IMG_20231005_170132_790.jpeg
#  IMG_20231006_131627_790.jpeg
#  IMG_20231006_131630_705.jpeg
#  IMG_20231006_131634_726.jpeg
#  IMG_20231006_131649_277.jpeg
#  IMG_20231006_131855_145.jpeg
#  IMG_20231006_131856_861.jpeg
#  IMG_20231006_131858_684.jpeg
#  IMG_20231006_133025_898.jpeg
#  IMG_20231006_133029_551.jpeg
#  IMG_20231006_133038_410.jpeg
#  IMG_20231006_133053_594.jpeg
#  IMG_20231006_133055_961.jpeg
#  IMG_20231006_133100_454.jpeg
#  IMG_20231006_140748_591.jpeg
#  IMG_20231006_140806_980.jpeg
#  IMG_20231006_140808_461.jpeg
#  IMG_20231006_140817_294.jpeg
#  IMG_20231006_140829_728.jpeg
#  IMG_20231006_141656_669.jpeg
#  IMG_20231006_141700_153.jpeg
#  IMG_20231006_141703_656.jpeg
#  IMG_20231006_141704_530.jpeg
#  IMG_20231006_141724_115.jpeg
#  IMG_20231006_141727_012.jpeg
#  IMG_20231006_141727_588.jpeg
#  IMG_20231006_141733_009.jpeg
#  IMG_20231006_141746_662.jpeg
#  IMG_20231006_142249_050.jpeg
#  IMG_20231006_142253_397.jpeg
#  IMG_20231006_142302_715.jpeg
#  IMG_20231006_142309_583.jpeg
#  IMG_20231006_142309_651.jpeg
#  IMG_20231006_142319_960.jpeg
#  IMG_20231006_142324_927.jpeg
#  IMG_20231006_142326_921.jpeg
#  IMG_20231006_142326_953.jpeg
#  IMG_20231006_142358_493.jpeg
#  IMG_20231006_142403_274.jpeg
#  IMG_20231006_142410_290.jpeg
#  IMG_20231006_142410_786.jpeg
#  IMG_20231006_142426_416.jpeg
#  IMG_20231006_142427_971.jpeg
#  IMG_20231006_142442_983.jpeg
#  IMG_20231006_142443_703.jpeg
#  IMG_20231006_142447_159.jpeg
#  IMG_20231006_142459_169.jpeg
#  IMG_20231006_142522_442.jpeg
#  IMG_20231006_142524_117.jpeg
#  IMG_20231006_142525_033.jpeg
#  IMG_20231006_142530_958.jpeg
#  IMG_20231006_142533_478.jpeg
#  IMG_20231006_142542_578.jpeg
#  IMG_20231006_142549_446.jpeg
#  IMG_20231006_142657_179.jpeg
#  IMG_20231006_142657_444.jpeg
#  IMG_20231006_142703_572.jpeg
#  IMG_20231006_142920_561.jpeg
#  IMG_20231006_142921_580.jpeg
#  IMG_20231006_142933_599.jpeg
#  IMG_20231006_142947_026.jpeg
#  IMG_20231006_142947_525.jpeg
#  IMG_20231006_143000_437.jpeg
#  IMG_20231006_143012_549.jpeg
#  IMG_20231006_143018_289.jpeg
#  IMG_20231006_143050_372.jpeg
#  IMG_20231006_143059_823.jpeg
#  IMG_20231006_143100_613.jpeg
#  IMG_20231006_143101_732.jpeg
#  IMG_20231006_143159_523.jpeg
#  IMG_20231006_143201_209.jpeg
#  IMG_20231006_143202_268.jpeg
#  IMG_20231006_143211_572.jpeg
#  IMG_20231006_143215_312.jpeg
#  IMG_20231006_143222_802.jpeg
#  IMG_20231006_143226_193.jpeg
#  IMG_20231006_143301_857.jpeg
#  IMG_20231006_143305_696.jpeg
#  IMG_20231006_143307_826.jpeg
#  IMG_20231006_143310_794.jpeg
#  IMG_20231006_143332_759.jpeg
#  IMG_20231006_143335_593.jpeg
#  IMG_20231006_143336_689.jpeg
#  IMG_20231006_143339_918.jpeg
#  IMG_20231006_143348_331.jpeg
#  IMG_20231006_143349_076.jpeg
#  IMG_20231006_143415_330.jpeg
#  IMG_20231006_143628_827.jpeg
#  IMG_20231006_143641_871.jpeg
#  IMG_20231006_143648_191.jpeg
#  IMG_20231006_143651_780.jpeg
#  IMG_20231006_143653_153.jpeg
#  IMG_20231006_143703_339.jpeg
#  IMG_20231006_143705_306.jpeg
#  IMG_20231006_143706_788.jpeg
#  IMG_20231006_143724_122.jpeg
#  IMG_20231006_143743_819.jpeg
#  IMG_20231006_143746_625.jpeg
#  IMG_20231006_143751_075.jpeg
#  IMG_20231006_143757_385.jpeg
#  IMG_20231006_143758_109.jpeg
#  IMG_20231006_143833_734.jpeg
#  IMG_20231006_143834_761.jpeg
#  IMG_20231006_143841_567.jpeg
#  IMG_20231006_143856_122.jpeg
#  IMG_20231006_143858_728.jpeg
#  IMG_20231006_143905_198.jpeg
#  IMG_20231006_143913_502.jpeg
#  IMG_20231006_143914_793.jpeg
#  IMG_20231006_143915_842.jpeg
#  IMG_20231006_143917_660.jpeg
#  IMG_20231006_143919_056.jpeg
#  IMG_20231006_143919_983.jpeg
#  IMG_20231006_143949_992.jpeg
#  IMG_20231006_143954_602.jpeg
#  IMG_20231006_143957_650.jpeg
#  IMG_20231006_144000_277.jpeg
#  IMG_20231006_144057_614.jpeg
#  IMG_20231006_144113_484.jpeg
#  IMG_20231006_144324_267.jpeg
#  IMG_20231006_144338_720.jpeg
#  IMG_20231006_144354_257.jpeg
#  IMG_20231006_144359_507.jpeg
#  IMG_20231006_144401_960.jpeg
#  IMG_20231006_144404_289.jpeg
#  IMG_20231006_144433_643.jpeg
#  IMG_20231006_144504_837.jpeg
#  IMG_20231006_144521_000.jpeg
#  IMG_20231006_144522_208.jpeg
#  IMG_20231006_144523_939.jpeg
#  IMG_20231006_145242_437.jpeg
#  IMG_20231006_145245_088.jpeg
#  IMG_20231006_145245_447.jpeg
#  IMG_20231006_145251_069.jpeg
#  IMG_20231006_145258_296.jpeg
#  IMG_20231006_150415_697.jpeg
#  IMG_20231006_150416_544.jpeg
#  IMG_20231006_150417_652.jpeg
#  IMG_20231007_162928_330.jpeg
#  IMG_20231007_162939_987.jpeg
#  IMG_20231007_162955_480.jpeg
#  IMG_20231007_163020_648.jpeg
#  IMG_20231007_163147_395.jpeg
#  IMG_20231007_163622_069.jpeg
#  IMG_20231007_163655_344.jpeg
#  IMG_20231007_163700_361.jpeg
#  IMG_20231007_163743_670.jpeg
#  IMG_20231007_163753_372.jpeg
#  IMG_20231007_163845_059.jpeg
#  IMG_20231007_163853_535.jpeg
#  IMG_20231007_163917_082.jpeg
#  IMG_20231007_163932_865.jpeg
#  IMG_20231007_163959_951.jpeg
#  IMG_20231007_164017_654.jpeg
#  IMG_20231007_164027_313.jpeg
#  IMG_20231007_164059_822.jpeg
#  IMG_20231007_164121_645.jpeg
#  IMG_20231007_164211_113.jpeg
#  IMG_20231007_164216_533.jpeg
#  IMG_20231007_164347_746.jpeg
#  IMG_20231007_164436_927.jpeg
#  IMG_20231007_164506_187.jpeg
#  IMG_20231007_164608_524.jpeg
#  IMG_20231007_164708_825.jpeg
#  IMG_20231007_164735_765.jpeg
#  IMG_20231007_164752_308.jpeg
#  IMG_20231007_164846_820.jpeg
#  IMG_20231007_165117_461.jpeg
#  IMG_20231007_165229_050.jpeg
#  MX_Acad_Center_001.jpeg
#  MX_AUDITORIUM_001.jpeg
#  MX_BLOCK_B_001.jpeg
#  MX_CSS_001.jpeg
#  MX_CSS_002.jpeg
#  MX_DCAL_1.jpeg
#  MX_Edwin_Clark_001.jpeg
#  MX_Edwin_Clark_003.jpeg
#  MX_Edwin_Clark_004.jpeg
#  MX_Edwin_Clark_005.jpeg
#  MX_Edwin_Clark_006.jpeg
#  MX_Edwin_Clark_007.jpeg
#  MX_Eng_Complex_001.jpeg
#  MX_Eng_Complex_002.jpeg
#  MX_Eng_Complex_003.jpeg
#  MX_Eng_Complex_004.jpeg
#  MX_Eng_Complex_005.jpeg
#  MX_Eng_LT1_001.jpeg
#  MX_Eng_LT1_002.jpeg
#  MX_Eng_LT1_003.jpeg
#  MX_Eng_LT1_004.jpeg
#  MX_IBB_1.jpeg
#  MX_IBB_2.jpeg
#  MX_IBB_3.jpeg
#  MX_ITS_DCAL_001.jpeg
#  MX_Mech_003.jpeg
#  MX_PST_001.jpeg
#  MX_PST_002.jpeg
#  MX_SAAT_001.jpeg
#  MX_SAAT_002.jpeg
#  MX_SAAT_003.jpeg
#  MX_SAAT_004.jpeg
#  MX_SET_001.jpeg
#  MX_SET_002.jpeg
#  MX_SET_003.jpeg
#  MX_SICT_001.jpeg
#  MX_SICT_002.jpeg
#  MX_SICT_003.jpeg
#  MX_SICT_004.jpeg
#  MX_SICT_005.jpeg
#  MX_SICT_006.jpeg
#  MX_SICT_LT_001.jpeg
#  MX_SIT_1.jpeg
#  MX_SIT_2.jpeg
#  MX_SLS_0015.jpeg
#  MX_SLS_001.jpeg
#  MX_SLS_002.jpeg
#  MX_SLS_003.jpeg
#  MX_SLS_004.jpeg
#  MX_SLS_005.jpeg
#  MX_SLS_006.jpeg
#  MX_SLS_007.jpeg
#  MX_SLS_008.jpeg
#  MX_SLS_009.jpeg
#  MX_SLS_010.jpeg
#  MX_SLS_0113.jpeg
#  MX_SLS_011.jpeg
#  MX_SLS_012.jpeg
#  MX_SLS_013.jpeg
#  MX_SLS_014.jpeg
#  MX_SLS_015.jpeg
#  MX_SLS_016.jpeg
#  MX_SLS_017.jpeg
#  MX_SLS_018.jpeg
#  MX_SLS_019.jpeg
#  MX_SLS_020.jpeg
#  MX_SLS_021.jpeg
#  MX_SLS_022.jpeg
#  MX_SLS_023.jpeg
#  MX_SLS_025.jpeg
#  MX_SLS_026.jpeg
#  MX_SPS_001.jpeg
#  MX_SPS_002.jpeg
#  MX_SPS_003.jpeg
#  MX_SPS_004.jpeg
#  MX_SPS_005.jpeg
#  MX_SPS_006.jpeg
#  MX_SPS_007.jpeg
#  MX_SPS_008.jpeg
#  MX_SPS_009.jpeg
#  MX_SPS_010.jpeg
#  MX_SPS_011.jpeg
#  MX_SPS_012.jpeg
#  MX_SPS_013.jpeg
#  MX_SPS_014.jpeg
#  MX_SPS_015.jpeg
#  MX_SPS_016.jpeg
#  MX_SPS_017.jpeg
#  MX_SPS_018.jpeg
#  MX_SPS_019.jpeg
#  MX_SPS_020.jpeg
#  MX_SPS_021.jpeg
#  MX_SPS_022.jpeg
#  MX_SPS_023.jpeg
#  MX_SPS_024.jpeg
#  MX_SPS_025.jpeg
#  MX_SPS_026.jpeg
#  MX_SPS_027.jpeg
#  MX_SPS_028.jpeg
#  MX_SPS_029.jpeg
#  MX_SPS_02.jpeg
#  MX_SPS_030.jpeg
#  MX_SPS_031.jpeg
#  MX_SPS_032.jpeg
#  MX_SPS_033.jpeg
#  MX_SPS_034.jpeg
#  MX_Tetfund_Workshop_001.jpeg
#  Omons_storey_building_01.jpeg
#  Omons_storey_building_02.jpeg
#  Omons_storey_building_03.jpeg
#  Omons_storey_building_04.jpeg
#  Omons_storey_building_05.jpeg
#  Omons_storye_building_06.jpeg
#  one-one-tosin.jpeg
#  poli_tosin.jpeg
#  poo-tosin.jpeg
#  sample_data
#  sam-tosin.jpeg
#  sl2-tosin.jpeg
#  sll-tosin.jpeg
#  sl-tosin.jpeg
# 'storey 2.jpeg'
# 'storey 3.jpeg'
#  storey_aug.jpeg
#  storey.jpeg
#  Storybuilding_aj_01.jpeg
#  Storybuilding_aj_02.jpeg
#  Storybuilding_aj_03.jpeg
#  Storybuilding_aj_04.jpeg
#  Storybuilding_aj_05.jpeg
#  Storybuilding_aj_06.jpeg
#  Storybuilding_aj_07.jpeg
#  Storybuilding_aj_08.jpeg
#  Storybuilding_aj_09.jpeg
#  Storybuilding_aj_10.jpeg
#  tosin001a.jpeg
#  tosin-00.jpeg
#  tosin01b.jpeg
#  tosin01c.jpeg
#  tosin01s.jpeg
#  tosin-099.jpeg
#  tosin100.jpeg
#  tosin-110.jpeg
#  tosin110.jpeg
#  tosin-111.jpeg
#  tosin-112.jpeg
#  tosin-113.jpeg
#  tosin-114.jpeg
#  tosin-115.jpeg
#  tosin-118.jpeg
#  tosin-119.jpeg
#  tosin-121.jpeg
#  tosin-122.jpeg
#  tosin-123.jpeg
#  tosin-124.jpeg
#  tosin-125.jpeg
#  tosin-126.jpeg
#  tosin-127.jpeg
#  tosin-1.jpeg
#  tosin-2.jpeg
#  tosin-3.jpeg
#  tosin-4.jpeg
#  tosin-5.jpeg
#  tosin66.jpeg
#  tosin-6.jpeg
#  tosin77.jpeg
#  tosin87.jpeg
#  tosin-8.jpeg
#  tosin99.jpeg
#  tosin-a.jpeg
#  tosin-b.jpeg
#  tosinbrt.jpeg
#  tosin-c.jpeg
#  tosin-e.jpeg
#  tosin-f.jpeg
#  tosin_gr.jpeg
#  tosin-hu.jpeg
#  tosin-ii.jpeg
#  tosin-j.jpeg
#  tosin-k.jpeg
#  tosin-m.jpeg
#  tosinnija.jpeg
#  tosin-n.jpeg
#  tosinn.jpeg
#  tosin-o.jpeg
#  tosin-sl.jpeg
#  tosin-uu.jpeg
#  wa-tosin.jpeg
#  well-tosin.jpeg
# 'WhatsApp Image 2023-10-09 at 19.17.24 (1).jpeg'
# 'WhatsApp Image 2023-10-09 at 19.17.25.jpeg'
# 'WhatsApp Image 2023-10-09 at 19.17.26.jpeg'
# 'WhatsApp Image 2023-10-09 at 19.17.27.jpeg'

# %%
import zipfile
import os

zip_file_path = "/content/your_uploaded_file.zip"
import zipfile
import os

zip_file_path = "/content/your_uploaded_file.zip"
# Extracting
extract_path = "/content/my_folder"
with zipfile.ZipFile("Building Types.zip", "r") as zip_ref:
    zip_ref.extractall(extract_path)

# Verify extraction
print("Extracted files:", os.listdir(extract_path))
# Verify extraction
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extracted files: ['__MACOSX', 'Building Types']
# Extracted files: ['__MACOSX', 'Building Types']

# %% [markdown]
# # Define Constants

# %%
IMAGE_HEIGHT = 400 # The height the image is to be resized to
IMAGE_WIDTH = 300 # The width the image is to be resized to
BATCH_SIZE = 32

# Define paths for data
data_dir = 'data' # Ensure the name of the folder is set to this.
class_names = ['Bungalow', 'Highrise', 'Storey-Building']

# %% [markdown]
# # Implement Data Generators and Preprocessing pipeline
#
# **This will create an easy preprocessing pipeline and will help load your data in batches**

# %%
# Set up data generators for training and testing
datagen = ImageDataGenerator(
    rescale=1./255,            # Normalize pixel values to [0,1]
    validation_split=0.2,      # 20% of data will be used for validation
    rotation_range=40,          # Rotate images by up to 40 degrees
    width_shift_range=0.2,     # Shift images horizontally by up to 20% of the width
    height_shift_range=0.2,    # Shift images vertically by up to 20% of the height
    shear_range=0.2,           # Apply shear transformations
    zoom_range=0.2,            # Zoom in or out by up to 20%
    horizontal_flip=True,       # Flip images horizontally
    fill_mode='nearest'         # Fill in missing pixels using the nearest neighbor
)

data_dir = 'my_folder/Building Types'

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 959 images belonging to 3 classes.
# Found 238 images belonging to 3 classes.

# %% [markdown]
# **Load InceptionV3 and Fine-Tune the Model**

# %%
#Loading the pre-trained model InceptionV3
base_model = tf.keras.applications.InceptionV3(
    weights='imagenet',  # Loading weights pre-trained on ImageNet
    include_top=False,
    input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))  # image dimensions


# Freezing the layers in the base model
base_model.trainable = False

# Adding custom layers on top of the pre-trained model
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),  # Pooling layer
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes for building types
])

# 4. Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 5. Train the model (fine-tuning)
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 466s 15s/step - accuracy: 0.5979 - loss: 0.8843 - val_accuracy: 0.7185 - val_loss: 0.5961
# Epoch 2/10
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 449s 15s/step - accuracy: 0.7950 - loss: 0.4830 - val_accuracy: 0.7605 - val_loss: 0.5402
# Epoch 3/10
# 17/30 ━━━━━━━━━━━━━━━━━━━━ 2:36 12s/step - accuracy: 0.8110 - loss: 0.4504

# %% [markdown]
# # Model architecture

# %%
# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Add a dropout layer with a rate of 0.5
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes for building types
])

# Compile the model
model.compile(optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Train the model

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)
# This part of the code allows you to train the model. You can decide to tweak the number of epochs by experimenting with different values.
# Rule of thumb: Avoid using too large epochs, to avoid overfitting.

# %% [markdown]
# # Evaluate the model

# %%
test_loss, test_acc = model.evaluate(validation_generator, verbose=2)
print(f'Test accuracy: {test_acc*100:.2f}%')

# %% [markdown]
# # Save the Model

# %%
path_to_save_model = 'path_to_save_model'

# Save the entire model (including architecture, weights, and optimizer state)
model.save(path_to_save_model)

# If you only want to save the model architecture and weights (without optimizer state)
# Uncomment the following line and comment out the previous 'model.save()' line
# model.save(path_to_save_model, save_format='tf')

# %% [markdown]
# ## **Changes made by Bagai Glory**
#
#
# 1.   I included Data Augumentation parameters withing the ImageDataGenrator
# 2.   Fine tuning the model using InceptionV3
# 3. Included the dropout function to manage overfitting in the data.
# 4. Implement a learning rate schedule or use adaptive learning rate methods like Adam.
